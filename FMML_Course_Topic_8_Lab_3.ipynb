# %% [markdown]
# <a href="https://colab.research.google.com/github/Kethimanikumar/FMML_course_assessments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-03 09:43:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   115MB/s    in 0.6s
#
# 2023-05-03 09:43:28 (115 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 292    1703.06585v2  We introduce the first goal-driven training fo...    cs
# 6262   1610.06664v1  Stochastic gradient MCMC (SG-MCMC) has played ...  stat
# 22806  1707.03010v1  Given the observation of a high-dimensional Or...  stat
# 3160    1309.3809v1  We consider the problem of naming objects in c...    cs
# 34888   1301.6265v4  Recent advances in associative memory design t...    cs
# ...             ...                                                ...   ...
# 39373  1601.04770v3  We propose an adaptive learning procedure to l...    cs
# 5624   1505.01866v1  Multiple Additive Regression Trees (MART), an ...    cs
# 7152   1710.09302v3  Deep Neural Networks (DNNs) are universal func...  stat
# 22586  1702.01125v1  This paper presents a novel data-driven techni...  stat
# 32203   1302.0540v1  In this paper, a novel approach for the optima...    cs
#
#                                                    title  year  \
# 292    Learning Cooperative Visual Dialog Agents with...  2017
# 6262       Stochastic Gradient MCMC with Stale Gradients  2016
# 22806  Sparse inference of the drift of a high-dimens...  2017
# 3160   Visual-Semantic Scene Understanding by Sharing...  2013
# 34888   Neural Networks Built from Unreliable Components  2013
# ...                                                  ...   ...
# 39373     Adaptive Image Denoising by Mixture Adaptation  2016
# 5624   DART: Dropouts meet Multiple Additive Regressi...  2015
# 7152                                Deep Neural Networks  2017
# 22586  Energy Prediction using Spatiotemporal Pattern...  2017
# 32203  A game-theoretic framework for classifier ense...  2013
#
#                                                 keywords
# 292    [introduce, answering, specifically, cooperati...
# 6262   [stochastic, important, developed, theoretical...
# 22806  [observation, dimensional, uhlenbeck, continuo...
# 3160   [containing, appearance, different, cognitive,...
# 34888  [associative, strutured, inference, algorithms...
# ...                                                  ...
# 39373  [procedure, denoising, algorithm, expectation,...
# 5624   [regression, regression, prediction, specializ...
# 7152   [universal, approximators, providing, solution...
# 22586  [technique, spatiotemporal, energypower, predi...
# 32203  [combination, classifiers, classifier, combina...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 292      [introduce, answering, specifically, cooperati...
# 6262     [stochastic, important, developed, theoretical...
# 22806    [observation, dimensional, uhlenbeck, continuo...
# 3160     [containing, appearance, different, cognitive,...
# 34888    [associative, strutured, inference, algorithms...
#                                ...
# 37533    [monitoring, behaviors, understand, particular...
# 27133    [recognition, questions, recognition, performa...
# 23989    [descriptors, descriptor, descriptors, informa...
# 31561    [disparity, different, algorithms, complementa...
# 36315    [definition, causality, intervention, componen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8811 words.
# Out of those 4535 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ffe557d8-654d-41bc-913f-d3e9eb0a197f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffe557d8-654d-41bc-913f-d3e9eb0a197f")) {                    Plotly.newPlot(                        "ffe557d8-654d-41bc-913f-d3e9eb0a197f",                        [{"x":["specified","introduce","ultimately","supervision","resulting","attributes","significantly","communicate","communication","outperform","reinforcement","informative","demonstration","emergence","vocabulary","specifically","experimental","experiments","cooperative","answering","demonstrate","supervised","interestingly","synthetic","questions","gradients","staleness","stochastic","effectiveness","algorithm","independent","indicates","developed","distributed","scalability","applications","properties","important","parameters","convergence","estimation","theoretical","increasingly","prescribed","asynchronously","demonstrating","approaches","financial","regression","penalization","including","illustrate","asymptotic","assumption","selection","dimensional","inequality","parameter","asymptotics","numerical","continuous","inference","eigenvalue","likelihood","restricted","simulations","mandatory","observation","penalized","consistency","procedure","represents","challenging","understanding","different","iterative","appearance","dirichlet","augmentation","maximizes","surpasses","integration","cognitive","containing","probabilities","performance","posterior","switching","allocation","hypotheses","computational","considers","characterize","threshold","exponential","unreliable","computations","retrieval","exceedingly","statistical","noiseless","components","probability","associative","algorithms","phenomenon","classical","internally","regularly","refinement","navigation","utterances","templates","locations","environment","collected","facilitate","collection","interface","developing","previously","adaptation","development","demonstrates","intermediate","collecting","graphical","unsupervised","constraints","primarily","correlations","probabilistic","sufficient","conditions","estimating","statistics","assumptions","tractable","distribution","identifiability","arbitrary","fundamental","principled","variables","optimization","expansion","increases","researchers","comparison","robustness","attention","frequency","implemented","conventional","denoising","traditional","characteristics","attracted","companies","correlation","sentiments","encourage","associated","dependent","industries","manufacturing","sentiment","encompassing","mentioned","perception","interacting","generally","analyzing","consumers","influence","enterprise","contained","proposals","outperforms","extremely","mechanism","automatic","leveraging","manipulation","rectangle","benchmark","typically","segmentation","particular","considerable","background","operation","rectangular","realizing","processing","distinguished","reasoning","languages","similarity","delivering"],"y":[33,340,17,59,160,70,287,15,58,116,116,28,13,16,40,190,360,597,23,52,542,206,23,150,67,29,1,128,202,773,155,21,165,116,32,414,221,345,255,103,198,154,46,3,3,31,454,14,130,1,256,78,19,59,148,183,8,125,1,71,116,219,3,51,63,33,2,48,4,56,126,52,273,153,762,62,69,24,35,17,7,44,51,50,54,911,38,11,27,28,285,37,45,23,48,10,34,98,2,155,1,116,148,11,571,13,101,6,5,24,33,16,7,36,130,69,32,50,37,57,89,75,128,54,31,14,57,129,149,16,20,157,56,133,53,59,86,25,202,2,76,89,19,137,292,14,45,73,131,95,173,68,85,100,37,182,103,20,14,81,10,14,99,86,3,11,48,5,15,41,21,74,61,6,57,4,23,35,251,41,129,185,39,19,2,208,111,219,289,45,76,44,9,7,304,8,135,102,142,3],"type":"bar"},{"x":["specified","introduce","ultimately","supervision","resulting","attributes","significantly","communicate","communication" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4535,), (4535, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3809523809523809);'>Reinforcement</span> <span style=''>Learning</span> <span style=''>in</span> <span style=''>Large</span> <span style=''>Discrete</span> <span style=''>Action</span> <span style=''>Spaces</span> <br/><br/><span style=''>Being</span> <span style=''>able</span> <span style=''>to</span> <span style=''>reason</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.6560509554140127);'>environment</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>actions</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.34883720930232553);'>essential</span> <span style=''>to</span> <span style=''>bringing</span> <span style='background-color:rgba(0, 255, 0, 0.3809523809523809);'>reinforcement</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>a</span> <span style=''>larger</span> <span style=''>class</span> <span style=''>of</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recommender</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industrial</span> <span style=''>plants</span> <span style=''>and</span> <span style=''>language</span> <span style=''>models</span> <span style=''>are</span> <span style=''>only</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style=''>many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>large</span> <span style=''>numbers</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>actions</span> <span style=''>for</span> <span style=''>which</span> <span style=''>current</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>or</span> <span style=''>even</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impossible</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>An</span> <span style=''>ability</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>over</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>sub</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>the</span> <span style=''>set</span> <span style=''>are</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>necessary</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>such</span> <span style=''>tasks</span> <span style=''>Current</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>are</span> <span style=''>not</span> <span style=''>able</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>both</span> <span style=''>of</span> <span style=''>these</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivates</span> <span style=''>the</span> <span style=''>work</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>Our</span> <span style=''>proposed</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>prior</span> <span style='back ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimality</span> <span style=''>of</span> <span style=''>Local</span> <span style=''>Search</span> <span style=''>for</span> <span style=''>Low</span> <span style=''>Rank</span> <span style=''>Matrix</span> <span style=''>Recovery</span> <br/><br/><span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>there</span> <span style=''>are</span> <span style=''>no</span> <span style=''>spurious</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>in</span> <span style=''>the</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>recovery</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incoherent</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>With</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>we</span> <span style=''>show</span> <span style=''>all</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>are</span> <span style=''>very</span> <span style=''>close</span> <span style=''>to</span> <span style=''>a</span> <span style=''>global</span> <span style=''>optimum</span> <span style=''>Together</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>bound</span> <span style=''>at</span> <span style=''>saddle</span> <span style=''>points</span> <span style=''>this</span> <span style=''>yields</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>em</span> <span style=''>from</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initialization</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Lipschitz</span> <span style=''>Bandits</span> <span style=''>Regret</span> <span style=''>Lower</span> <span style=''>Bounds</span> <span style=''>and</span> <span style=''>Optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.3710073710073711);'>stochastic</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problems</span> <span style=''>where</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Lipschitz</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>arm</span> <span style=''>and</span> <span style=''>where</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>arms</span> <span style=''>is</span> <span style=''>either</span> <span style=''>discrete</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>For</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Lipschitz</span> <span style=''>bandits</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.6448598130841121);'>asymptotic</span> <span style=''>problem</span> <span style=''>specific</span> <span style=''>lower</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>regret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>satisfied</span> <span style=''>by</span> <span style=''>any</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>OSLB</span> <span style=''>and</span> <span style=''>CKL</span> <span style=''>UCB</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>In</span> <span style=''>fact</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>OSLB</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.4035087719298245);'>asymptotically</span> <span style=''>optimal</span> <span style=''>as</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.6448598130841121);'>asymptotic</span> <span style=''>regret</span> <span style=''>matches</span> <span style=''>the</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>The</span> <span style=''>regret</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.6666666666666667);'>concentration</span> <span style='background-color:rgba(255, 0, 0, 0.46666666666666673);'>inequality</span> <span style=''>for</span> <span style=''>weighted</span> <span style=''>sums</span> <span style=''>of</span> <span style=''>KL</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333332);'>divergences</span> <span style=''>between</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Automatic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Programming</span> <span style=''>from</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>languages</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>complex</span> <span style=''>data</span> <span style=''>with</span> <span style=''>intermingled</span> <span style=''>models</span> <span style=''>in</span> <span style=''>a</span> <span style=''>few</span> <span style=''>lines</span> <span style=''>of</span> <span style=''>code</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>languages</span> <span style=''>make</span> <span style=''>possible</span> <span style=''>to</span> <span style=''>build</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frameworks</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>of</span> <span style=''>various</span> <span style=''>large</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <span style=''>When</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>model</span> <span style=''>is</span> <span style=''>given</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>program</span> <span style=''>is</span> <span style=''>rather</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>straightforward</span> <span style=''>Thus</span> <span style=''>main</span> <span style=''>focus</span> <span style=''>have</span> <span style=''>been</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>best</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>compute</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>to</span> <span style=''>build</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>program</span> <span style=''>from</span> <span style=''>continue</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>when</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>model</span> <span style=''>is</span> <span style=''>not</span> <span style=''>given</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08455750627015407)
# 	representation (0.1307774991042637)
# 	processing (0.10892153350053745)
# 	segmentation (0.07846649946255822)
# 	knowledge (0.14009315657470442)
# 	information (0.2522393407380867)
# 	detection (0.1293443210318882)
# 	recognition (0.12755284844141884)
# 	different (0.27302042278753136)
# 	convolutional (0.1443926907918309)
#
# Some Statistics words are:
# 	variables (0.13937282229965156)
# 	stochastic (0.13887506222000995)
# 	theoretical (0.15480338476854155)
# 	statistical (0.15729218516674962)
# 	distribution (0.18118466898954705)
# 	estimation (0.18417122946739672)
# 	algorithm (0.3932304629168741)
# 	dimensional (0.18218018914883027)
# 	inference (0.2025883524141364)
# 	regression (0.17670482827277254)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fa98bed3-3389-48b6-b84d-9492d4c79790" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa98bed3-3389-48b6-b84d-9492d4c79790")) {                    Plotly.newPlot(                        "fa98bed3-3389-48b6-b84d-9492d4c79790",                        [{"x":["specified","introduce","ultimately","supervision","resulting","attributes","significantly","communicate","communication","outperform","reinforcement","informative","demonstration","emergence","vocabulary","specifically","experimental","experiments","cooperative","answering","demonstrate","supervised","interestingly","synthetic","questions","gradients","staleness","stochastic","effectiveness","algorithm","independent","indicates","developed","distributed","scalability","applications","properties","important","parameters","convergence","estimation","theoretical","increasingly","prescribed","asynchronously","demonstrating","approaches","financial","regression","penalization","including","illustrate","asymptotic","assumption","selection","dimensional","inequality","parameter","asymptotics","numerical","continuous","inference","eigenvalue","likelihood","restricted","simulations","mandatory","observation","penalized","consistency","procedure","represents","challenging","understanding","different","iterative","appearance","dirichlet","augmentation","maximizes","surpasses","integration","cognitive","containing","probabilities","performance","posterior","switching","allocation","hypotheses","computational","considers","characterize","threshold","exponential","unreliable","computations","retrieval","exceedingly","statistical","noiseless","components","probability","associative","algorithms","phenomenon","classical","internally","regularly","refinement","navigation","utterances","templates","locations","environment","collected","facilitate","collection","interface","developing","previously","adaptation","development","demonstrates","intermediate","collecting","graphical","unsupervised","constraints","primarily","correlations","probabilistic","sufficient","conditions","estimating","statistics","assumptions","tractable","distribution","identifiability","arbitrary","fundamental","principled","variables","optimization","expansion","increases","researchers","comparison","robustness","attention","frequency","implemented","conventional","denoising","traditional","characteristics","attracted","companies","correlation","sentiments","encourage","associated","dependent","industries","manufacturing","sentiment","encompassing","mentioned","perception","interacting","generally","analyzing","consumers","influence","enterprise","contained","proposals","outperforms","extremely","mechanism","automatic","leveraging","manipulation","rectangle","benchmark","typically","segmentation","particular","considerable","background","operation","rectangular","realizing","processing","distinguished","reasoning","languages","similarity","delivering","semantics","universal","portuguese","automated","interoperability","accessibility","proceedings","thesaurus","resources","ontologies","construct","recognition","annotations","knowledge","processes","information","disambiguation","cornerstones","continues","maintenance","propositions","dictionaries","extraction","directions","successful","application","strategies","contextual","increased","annotated","treebanks","incredible","technique","resolution","classification","additional","investigate","threefold","evaluating","potentially","potential","buildings","discriminative","interpret","recognize","parsimonious","technology","capability","contribution","convolutional","misclassification","assistive","furthermore","multiscale","activating","validation","equivalent","distributions","co ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	epidemiology
# 	acceptancerejection
# 	solvation
# 	periodicity
# 	transformative
# 	chemception
# 	unnormalized
# 	phenotyping
# 	distinguishability
# 	transports
# 	blockmodel
# 	mislabeled
# 	mcallester
# 	incidentally
# 	emphmulti
# 	heteroskedastic
# 	formalizes
# 	distributionally
# 	robustification
# 	marginalize
# Some words which never appear in Statistics papers:
# 	surpasses
# 	exceedingly
# 	navigation
# 	portuguese
# 	interoperability
# 	accessibility
# 	thesaurus
# 	disambiguation
# 	treebanks
# 	incredible
# 	buildings
# 	assistive
# 	narrative
# 	antagonistic
# 	superiorities
# 	mitigated
# 	contrarily
# 	inconsistencies
# 	observers
# 	symmetrical

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082139004469102e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
